# %% [markdown]
# <a href="https://colab.research.google.com/github/AnshulMenaria/CitySpace/blob/main/Day_6_Assignment_IF_Conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Write a program that takes a user input of three angles and will find out whether it
# can form a triangle or not.

a=int(input("Enter the first angle: "))
b=int(input("Enter the second angle: "))
c=int(input("Enter the third angle: "))

if a+b>c and b+c>a and c+a>b:
    print("It can form a triangle")
else:
    print("It can't form a triangle")
# Out:
# Enter the first angle: 5
# Enter the second angle: 6
# Enter the third angle: 4
# It can form a triangle

# %%
# 2. Write a program that will determine weather when the value of temperature and
# humidity is provided by the user.
# Temperature(C)    Humidity(%)     Weather
#   >=30              >=90          Hot and Humid
#   >=30              <90           Hot
#   <30               >=90          Cool and Humid
#   <30               <90           cool

temp=int(input("Enter the temperature: "))
hum=int(input("Enter the humidity: "))

if temp>=30 and hum>=90:
    print("Hot and Humid")
elif temp>=30 and hum<90:
    print("Hot")
elif temp<30 and hum>=90:
    print("Cool and Humid")
elif temp<30 and hum<90:
    print("Cool")
else:
    print("Invalid input")
# Out:
# Enter the temperature: 40
# Enter the humidity: 89
# Hot

# %%
# 3. Write a program that will take user input of cost price and selling price and
# determines whether its a loss or a profit

cost_price=int(input("Enter Cost Price:"))
selling_price=int(input("Enter Selling Price:"))
total=selling_price-cost_price
if(total>0):
  print("Profit")
elif(total<0):
  print("Loss")
elif(total==0):
  print("Cost Price, No Profit And No Loss")
else:
  print("Invalid")
# Out:
# Enter Cost Price:50
# Enter Selling Price:40
# Sold in Loss

# %%
# 4. Write a program that will tell the number of dogs and chicken are there when the user
# will provide the value of total heads and legs.
# a. Input are
# b. head=1 , legs=4

#find dogs and chickens using heads and legs

# %%
# 5. Program to check whether a number is divisible by 5 and 11 or not

num=int(input("Enter Number To Check if it is divisible by 5 and 11:"))
if(num%5==0 and num%11==0):
    print("Number is divisible by 5 and 11")
else:
  print("Number is not divisible by 5 and 11")
# Out:
# Enter Number To Check if it is divisible by 5 and 11:55
# Number is divisible by 5 and 11

# %%
# 6. Write a program to check whether triangle is valid or not if angles are given.

a=int(input("Enter the first angle: "))
b=int(input("Enter the second angle: "))
c=int(input("Enter the third angle: "))
if(a+b+c==180 and a>0 and b>0 and c>0):
  print("Valid Triangle!")
else:
  print("Invalid Triangle!")
# Out:
# Enter the first angle: 60
# Enter the second angle: 60
# Enter the third angle: 60
# Valid Triangle!

# %%
# 7. Write a program to check whether triangle is equilateral, scalene or isosceles
# a. A triangle is said Equilateral Triangle, if all its sides are equal. If a, b, c are
# three sides of triangle. Then, the triangle is equilateral only if a == b == c
# b. A triangle is said Isosceles Triangle, if its two sides are equal. If a, b, c are
# three sides of triangle. Then, the triangle is isosceles if either a == b or a == c
# or b == c.
# c. A triangle is said Scalene Triangle, if none of its sides are equal.

a = int(input("Enter the length of side a: "))
b = int(input("Enter the length of side b: "))
c = int(input("Enter the length of side c: "))

if(a==b==c):
  print("Equilateral Triangle")
elif(a==b or a==c or b==c):
  print("Isosceles Triangle")
elif(a!=b and a!=c and b!=c):
  print("Scalene Triangle")
else:
  print("Invalid")
# Out:
# Enter the length of side a: 20
# Enter the length of side b: 30
# Enter the length of side c: 20
# Isosceles Triangle

# %%
# 8. Write a program to enter basic salary and calculate gross salary of an employee
# Basic Salary <=10000: HRA=20%, DA=80%
# Basic Salary is between 100001 to 20000: HRA=25%, DA=90%
# Basic Salary >=20001: HRA=30%, DA=95%

basic_salary = int(input("Enter Basic Salary: "))
if(basic_salary<=10000):
  hra=0.2*basic_salary
  da=0.8*basic_salary
  gross_salary=basic_salary+hra+da
  print("Gross Salary:",gross_salary)
elif(basic_salary>=10001 and basic_salary<=20000):
  hra=0.25*basic_salary
  da=0.9*basic_salary
  gross_salary=basic_salary+hra+da
  print("Gross Salary:",gross_salary)
elif(basic_salary>=20001):
  hra=0.3*basic_salary
  da=0.95*basic_salary
  gross_salary=basic_salary+hra+da
  print("Gross Salary:",gross_salary)
else:
  print("Invalid")
# Out:
# Enter Basic Salary: 15000
# Gross Salary: 32250.0

# %%
# 9. Write a program to calculate the total electricity bill based on the following conditions:
# a. The first 50 unit will be calculated with 2 rs/unit
# b. The next 100 unit will be calculated with 5 rs/unit
# c. The next 150 unit will be calculated with 10 rs/unit
# d. All the other units will be calculated with 15 rs/unit

units = int(input("Enter the number of units consumed: "))

if units <= 50:
  bill = units * 2
elif units <= 150:
  bill = 50 * 2 + (units - 50) * 5
elif units <= 300:
  bill = 50 * 2 + 100 * 5 + (units - 150) * 10
else:
  bill = 50 * 2 + 100 * 5 + 150 * 10 + (units - 300) * 15

print("Total electricity bill: Rs.", bill)

# %%
# 10. Write a program to check whether any year is a leap year or not
# a. A leap year is exactly divisible by 4 except for century years (years ending
# with 00). The century year is a leap year only if it is perfectly divisible by 400.

year = int(input("Enter a year: "))

if (year%4==0 and year%100!=0 or year%400==0):
  print(year, "is a leap year")
else:
  print(year, "is not a leap year")
# Out:
# Enter a year: 2000
# 2000 is a leap year

# %%
# 11. Write a program that will reverse a four digit number.Also it checks whether the
# reverse

num = int(input("Enter a four-digit number: "))

reversed_num = int(str(num)[::-1])

if num == reversed_num:
  print(num, "is a palindrome")
else:
  print(num, "is not a palindrome")
# Out:
# Enter a four-digit number: 3456
# 3456 is not a palindrome

# %%
# 12. Write a program that will check whether the number is armstrong number or not

num=int(input("Enter a number:"))
sum=0
temp=num
digit=0
power=len(str(num))
while(num>0):
  digit=num%10
  sum=sum+digit**power
  num=num//10
if(sum==temp):
  print("Armstrong Number")
else:
  print("Not Armstrong Number")
# Out:
# Enter a number:153
# Armstrong Number
